# %%
# !git clone https://github.com/pavelshapka/auto_karel_synthesis.git
# !cd auto_karel_synthesis

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/autom-lab2/karel-dataset.zip -d /content/auto_karel_synthesis/
# Out:
# Archive:  /content/drive/MyDrive/autom-lab2/karel-dataset.zip
#    creating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a.thdump
#    creating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/beeperSquare.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/border.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/buildEfes.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/checkerboard.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/clear.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/clearSquare.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/diagonal.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/doubleBeepers.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/doubleSquare.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/fill.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/fillPotholes.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/fourInARow.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/infinity.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/inset.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/maze.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/midpoint.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/mountain.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/newspaper.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/place100.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/place9.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/cs106a/plantTrees.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc.thdump
#    creating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc1.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc10.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc11.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc12.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc13.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc14.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc15.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc16.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc17.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc18.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc19.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc2.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc20.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc3.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc4.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc5.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc6.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc7.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc8.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/challenge/hoc/hoc9.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/new_vocab.vocab
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/target.vocab
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/test.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/test.thdump
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/train.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/val.json
#   inflating: /content/auto_karel_synthesis/1m_6ex_karel/val.thdump

# %%
DATASET_DIR = "/content/auto_karel_synthesis/1m_6ex_karel"
ROWS_COUNT = -1

with open(f"{DATASET_DIR}/train.json", "r") as f:
	ROWS_COUNT = sum(1 for _ in f)

print(ROWS_COUNT)
# Out:
# 1116854

# %%
percentiles = {
	"0.1": int(ROWS_COUNT * 0.001),
	"1": int(ROWS_COUNT * 0.01),
	"3": int(ROWS_COUNT * 0.03),
	"10": int(ROWS_COUNT * 0.1),
}

for p, row_count in percentiles.items():
	with open(f"{DATASET_DIR}/train.json", "r") as f:
		with open(f"{DATASET_DIR}/train_p_{p}.json", "w") as f_p:
			for _ in range(row_count):
				f_p.write(f.readline())

# %%
import json

def get_dataset_row_iter(filename: str):
	with open(filename, "r") as f:
		for line in f:
			yield json.loads(line)


it = get_dataset_row_iter(f"{DATASET_DIR}/train.json")

# %%
total

for row in it:
# Out:
# <class 'generator'>
# {'examples': [{'actions': ['turnLeft', 'move', 'turnLeft', 'turnRight', 'turnLeft', 'turnRight', 'turnLeft', 'turnRight', 'turnLeft', 'turnRight', 'pickMarker'], 'example_index': 0, 'inpgrid_json': {'blocked': '9:3 8:13 6:0 6:8 5:0 5:6 3:10 2:9 0:10', 'cols': 14, 'crashed': False, 'hero': '8:0:south', 'markers': '9:5:1 8:1:1 8:10:1 8:11:3 7:6:1 7:7:1 7:10:1 6:5:1 4:9:4 2:0:1 1:6:3 1:7:3 0:13:1', 'rows': 10}, 'inpgrid_tensor': '811:1.0 2130:1.0 2108:1.0 2117:1.0 2766:1.0 2095:1.0 2096:1.0 2099:1.0 2076:1.0 3016:1.0 1999:1.0 2635:1.0 2636:1.0 1976:1.0 1480:1.0 1472:1.0 1423:1.0 1431:1.0 1405:1.0 1411:1.0 1379:1.0 1360:1.0 1325:1.0 1620:1.0 1621:1.0 1622:1.0 1623:1.0 1624:1.0 1625:1.0 1626:1.0 1627:1.0 1628:1.0 1629:1.0 1630:1.0 1631:1.0 1632:1.0 1633:1.0 1634:1.0 1635:1.0 1818:1.0 1819:1.0 1820:1.0 1821:1.0 1822:1.0 1823:1.0 1824:1.0 1825:1.0 1826:1.0 1827:1.0 1828:1.0 1829:1.0 1830:1.0 1831:1.0 1832:1.0 1833:1.0 1638:1.0 1656:1.0 1674:1.0 1692:1.0 1710:1.0 1728:1.0 1746:1.0 1764:1.0 1782:1.0 1800:1.0 1653:1.0 1671:1.0 1689:1.0 1707:1.0 1725:1.0 1743:1.0 1761:1.0 1779:1.0 1797:1.0 1815:1.0', 'outgrid_json': {'blocked': '9:3 8:13 6:0 6:8 5:0 5:6 3:10 2:9 0:10', 'cols': 14, 'crashed': False, 'hero': '8:1:east', 'markers': '9:5:1 8:10:1 8:11:3 7:6:1 7:7:1 7:10:1 6:5:1 4:9:4 2:0:1 1:6:3 1:7:3 0:13:1', 'rows': 10}, 'outgrid_tensor': '488:1.0 2130:1.0 2
# %%
import os

print(os.listdir("./sample_data/"))

with open("./1m_6ex_karel/train.json", "r") as f:
	for _ in range(10):
		line = f.readline()
		print(line[:100])
# Out:
# ['README.md', 'anscombe.json', 'california_housing_test.csv', 'california_housing_train.csv', 'mnist_test.csv', 'mnist_train_small.csv']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2328924802.py in <cell line: 0>()
#       3 print(os.listdir("./sample_data/"))
#       4
# ----> 5 with open("./1m_6ex_karel/train.json", "r") as f:
#       6         for _ in range(10):
#       7                 line = f.readline()
#
# FileNotFoundError: [Errno 2] No such file or directory: './1m_6ex_karel/train.json'

# %%
# !curl ipinfo.io/city
# Out:
# Taipei
